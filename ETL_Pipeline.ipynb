# %%
#importing packages
import pymongo
import pandas as pd
from pymongo import MongoClient

# %%
# To access the data from mongo DB cloud and load it to dataframe
#client = MongoClient()
#point the client at mongo URI
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
#select database
db = client['LeeL_Interlinings']
#select the collection within the database
test = db.Business_Lead_Table
#convert entire collection to Pandas dataframe
data1_raw_Business_Lead_Table = pd.DataFrame(list(test.find()))

# %%
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
db = client['LeeL_Interlinings']
test = db.Customer_table
data2_raw_Customer_table = pd.DataFrame(list(test.find()))

# %%
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
db = client['LeeL_Interlinings']
test = db.Fabric_Type
data3_raw_Fabric_Type = pd.DataFrame(list(test.find()))

# %%
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
db = client['LeeL_Interlinings']
test = db.Feedback
data4_raw_Feedback= pd.DataFrame(list(test.find()))

# %%
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
db = client['LeeL_Interlinings']
test = db.Sales_Of_Fabrics
data5_raw_Sales_Of_Fabrics = pd.DataFrame(list(test.find()))

# %%
# To access the data from mongo DB cloud and load it to dataframe
#client = MongoClient()
#point the client at mongo URI
client = MongoClient('mongodb+srv://dabteam:dab@cluster0.tqgtu.mongodb.net/test')
#select database
db = client['LeeL_Interlinings']
#select the collection within the database
test = db.Transaction_Details
#convert entire collection to Pandas dataframe
data6_raw_Transaction_Details= pd.DataFrame(list(test.find()))

# %%
data1_raw_Business_Lead_Table
# Out:
#                           _id  Customer id Customer Name   \
# 0    62407ddc640453f94ca2a1c2            1       Barbabra
# 1    62407ddc640453f94ca2a1c3            2           Pate
# 2    62407ddc640453f94ca2a1c4            3      Aristotle
# 3    62407ddc640453f94ca2a1c5            4         Editha
# 4    62407ddc640453f94ca2a1c6            5        Hoebart
# ..                        ...          ...            ...
# 995  62407ddc640453f94ca2a5a5          996        Aeriell
# 996  62407ddc640453f94ca2a5a6          997           Andy
# 997  62407ddc640453f94ca2a5a7          998         Bobbie
# 998  62407ddc640453f94ca2a5a8          999         Benson
# 999  62407ddc640453f94ca2a5a9         1000          Carla
#
#                  Customer Email Customer contact no Fabric Type  \
# 0       aboorman0@blinklist.com       (153) 9758658      Poplin
# 1              fdilger1@aol.com       (397) 5392440      Poplin
# 2     ajaniak2@reverbnation.com       (527) 9381959        Jute
# ...

# %%
data2_raw_Customer_table
# Out:
#                           _id  Customer ID  Customer Name  \
# 0    62407ddd640453f94ca2a5ab             1      Barbabra
# 1    62407ddd640453f94ca2a5ac             2          Pate
# 2    62407ddd640453f94ca2a5ad             3     Aristotle
# 3    62407ddd640453f94ca2a5ae             4        Editha
# 4    62407ddd640453f94ca2a5af             5       Hoebart
# ..                        ...           ...           ...
# 995  62407ddd640453f94ca2a98e           996       Aeriell
# 996  62407ddd640453f94ca2a98f           997          Andy
# 997  62407ddd640453f94ca2a990           998        Bobbie
# 998  62407ddd640453f94ca2a991           999        Benson
# 999  62407ddd640453f94ca2a992          1000         Carla
#
#                    Customer Email  Quantity   Sales
# 0                tsearston0@51.la      6080  382.808
# 1         ofricke1@prnewswire.com      5849  358.177
# 2               aramirez2@icq.com       749  470.312
# 3                   gkopf3@goo.gl      7102  763.317
# ...

# %%
data3_raw_Fabric_Type
# Out:
#                           _id    ID Fabric Type Fabric Color  \
# 0    62407dde640453f94ca2a994     1      Poplin          Red
# 1    62407dde640453f94ca2a995     2      Poplin       Purple
# 2    62407dde640453f94ca2a996     3        Jute         Mauv
# 3    62407dde640453f94ca2a997     4      Sateen   Aquamarine
# 4    62407dde640453f94ca2a998     5        Lace         Teal
# ..                        ...   ...         ...          ...
# 995  62407dde640453f94ca2ad77   996      Sateen       Yellow
# 996  62407dde640453f94ca2ad78   997        Lace         Pink
# 997  62407dde640453f94ca2ad79   998        Lace         Pink
# 998  62407dde640453f94ca2ad7a   999        Jute       Indigo
# 999  62407dde640453f94ca2ad7b  1000     Cotton     Goldenrod
#
#               Design   Quantity
# 0              Floral      6080
# 1           Polka Dot      5849
# 2             Stripes       749
# 3                Ikat      7102
# 4        Flame Stitch      6803
# ..                ...       ...
# ...

# %%
data4_raw_Feedback
# Out:
#                           _id  Feedback ID  Customer ID  On Time Delivery  \
# 0    62407ddf640453f94ca2ad7d  85-874-8147            1             False
# 1    62407ddf640453f94ca2ad7e  21-876-6739            2              True
# 2    62407ddf640453f94ca2ad7f  52-642-1953            3              True
# 3    62407ddf640453f94ca2ad80  74-622-9955            4              True
# 4    62407ddf640453f94ca2ad81  15-020-3967            5             False
# ..                        ...          ...          ...               ...
# 995  62407ddf640453f94ca2b160  86-444-4119          996              True
# 996  62407ddf640453f94ca2b161  55-326-4821          997             False
# 997  62407ddf640453f94ca2b162  03-117-1387          998              True
# 998  62407ddf640453f94ca2b163  06-185-9690          999             False
# 999  62407ddf640453f94ca2b164  25-976-6934         1000             False
#
#      Quality  Is the style appealing
# 0       True                    True
# ...

# %%
data5_raw_Sales_Of_Fabrics
# Out:
#                           _id    ID  Customer ID  Customer Name      Segment  \
# 0    62407e11640453f94ca2b167     1             1       Barbabra   Consumer
# 1    62407e11640453f94ca2b168     2             2           Pate  Corporate
# 2    62407e11640453f94ca2b169     3             3      Aristotle   Consumer
# 3    62407e11640453f94ca2b16a     4             4         Editha  Corporate
# 4    62407e11640453f94ca2b16b     5             5        Hoebart   Consumer
# ..                        ...   ...           ...            ...         ...
# 995  62407e11640453f94ca2b54a   996           996        Aeriell   Consumer
# 996  62407e11640453f94ca2b54b   997           997           Andy   Consumer
# 997  62407e11640453f94ca2b54c   998           998         Bobbie  Corporate
# 998  62407e11640453f94ca2b54d   999           999         Benson   Consumer
# 999  62407e11640453f94ca2b54e  1000          1000          Carla  Corporate
#
# ...

# %%
data6_raw_Transaction_Details
# Out:
#                           _id    ID  Customer ID        Date Transaction
# 0    6240885f062464d7c207c155     1   2136567896   9/16/2021      Unpaid
# 1    6240885f062464d7c207c156     2   3265110877  06/07/2021      Unpaid
# 2    6240885f062464d7c207c157     3   1801705046   5/16/2021      Unpaid
# 3    6240885f062464d7c207c158     4   5005787259  11/25/2021      Unpaid
# 4    6240885f062464d7c207c159     5   1935535838   6/22/2021        Paid
# ..                        ...   ...          ...         ...         ...
# 995  6240885f062464d7c207c538   996   2099083592   6/23/2021        Paid
# 996  6240885f062464d7c207c539   997   8582117582   5/28/2021      Unpaid
# 997  6240885f062464d7c207c53a   998   9722937537   7/18/2021      Unpaid
# 998  6240885f062464d7c207c53b   999   4830417579  08/09/2021        Paid
# 999  6240885f062464d7c207c53c  1000   4299378539  10/16/2021      Unpaid
#
# [1000 rows x 5 columns]

# %% [markdown]
# data1_raw_Business_Lead_Table
#
# data2_raw_Customer_table
#
# data3_raw_Fabric_Type
#
# data4_raw_Feedback
#
# data5_raw_Sales_Of_Fabrics
#
# data6_raw_Transaction_Details

# %% [markdown]
# Transformations in data 1
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 1
data1_raw_Business_Lead_Table.drop("_id", axis=1, inplace=True)
import seaborn as sns
#displaying heatmap for visualizing null values in rawdataset
sns.heatmap(data1_raw_Business_Lead_Table.isnull(), cmap='viridis')
data1_raw_Business_Lead_Table.isnull().sum()
# Out:
# Customer id            0
# Customer Name          0
# Customer Email         0
# Customer contact no    0
# Fabric Type            0
#  Design                0
# Fabric Colour          0
# Order Priority         0
# Delivery Time          0
# Source of Product      0
# Sales                  0
# dtype: int64

# %%
data1_raw_Business_Lead_Table
# Out:
#      Customer id Customer Name               Customer Email  \
# 0              1       Barbabra     aboorman0@blinklist.com
# 1              2           Pate            fdilger1@aol.com
# 2              3      Aristotle   ajaniak2@reverbnation.com
# 3              4         Editha             chapper3@ft.com
# 4              5        Hoebart            eglavis4@sun.com
# ..           ...            ...                         ...
# 995          996        Aeriell  nlaughtissern@so-net.ne.jp
# 996          997           Andy      nfonzoro@delicious.com
# 997          998         Bobbie        ktournayrp@cam.ac.uk
# 998          999         Benson         ssnazelrq@upenn.edu
# 999         1000          Carla       mizachikrr@smh.com.au
#
#     Customer contact no Fabric Type           Design  Fabric Colour  \
# 0         (153) 9758658      Poplin            Floral        Violet
# 1         (397) 5392440      Poplin         Polka Dot          Pink
# ...

# %% [markdown]
# Transformation in data 2
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 2
data2_raw_Customer_table.drop("_id", axis=1, inplace=True)
import seaborn as sns
#displaying heatmap for visualizing null values in rawdataset
sns.heatmap(data2_raw_Customer_table.isnull(), cmap='viridis')
data2_raw_Customer_table.isnull().sum()
# Out:
# Customer ID       0
# Customer Name     0
# Customer Email    0
# Quantity          0
# Sales             0
# dtype: int64

# %%
data2_raw_Customer_table
# Out:
#      Customer ID  Customer Name                Customer Email  Quantity  \
# 0               1      Barbabra              tsearston0@51.la      6080
# 1               2          Pate       ofricke1@prnewswire.com      5849
# 2               3     Aristotle             aramirez2@icq.com       749
# 3               4        Editha                 gkopf3@goo.gl      7102
# 4               5       Hoebart      gdarville4@clickbank.net      6803
# ..            ...           ...                           ...       ...
# 995           996       Aeriell    lreidrn@washingtonpost.com      3065
# 996           997          Andy              mhaithro@irs.gov      3332
# 997           998        Bobbie  cgoodliffrp@domainmarket.com      3323
# 998           999        Benson         tklimshukrq@patch.com      5301
# 999          1000         Carla          krobbertrr@ameblo.jp      9707
#
#       Sales
# 0    382.808
# 1    358.177
# 2    470.312
# 3    763.317
# 4    592.887
# ..       ...
# ...

# %% [markdown]
# Transformation in data 3
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 3
data3_raw_Fabric_Type.drop("_id", axis=1, inplace=True)
import seaborn as sns
#displaying heatmap for visualizing null values in rawdataset
sns.heatmap(data3_raw_Fabric_Type.isnull(), cmap='viridis')
data3_raw_Fabric_Type.isnull().sum()
# Out:
# ID              0
# Fabric Type     0
# Fabric Color    0
#  Design         0
# Quantity        0
# dtype: int64

# %%
data3_raw_Fabric_Type
# Out:
#        ID Fabric Type Fabric Color           Design   Quantity
# 0       1      Poplin          Red            Floral      6080
# 1       2      Poplin       Purple         Polka Dot      5849
# 2       3        Jute         Mauv           Stripes       749
# 3       4      Sateen   Aquamarine              Ikat      7102
# 4       5        Lace         Teal      Flame Stitch      6803
# ..    ...         ...          ...               ...       ...
# 995   996      Sateen       Yellow  Vinatge Seamless      3065
# 996   997        Lace         Pink    Retro Seamless      3332
# 997   998        Lace         Pink    Retro Seamless      3323
# 998   999        Jute       Indigo      Flame Stitch      5301
# 999  1000     Cotton     Goldenrod         Polka Dot      9707
#
# [1000 rows x 5 columns]

# %% [markdown]
# Transformation in data 4
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 4
data4_raw_Feedback.drop("_id", axis=1, inplace=True)

# %%
extracted_col = data1_raw_Business_Lead_Table["Source of Product"]
# display(extracted_col)
data1_raw_Business_Lead_Table.drop("Source of Product", axis=1, inplace=True)
data4_raw_Feedback = data4_raw_Feedback.join(extracted_col)

# %%
import seaborn as sns
#displaying heatmap for visualizing null values in rawdataset
sns.heatmap(data4_raw_Feedback.isnull(), cmap='viridis')
data4_raw_Feedback.isnull().sum()
# Out:
# Feedback ID               0
# Customer ID               0
# On Time Delivery          0
# Quality                   0
# Is the style appealing    0
# Source of Product         0
# dtype: int64

# %%
data4_raw_Feedback
# Out:
#      Feedback ID  Customer ID  On Time Delivery  Quality  \
# 0    85-874-8147            1             False     True
# 1    21-876-6739            2              True    False
# 2    52-642-1953            3              True    False
# 3    74-622-9955            4              True     True
# 4    15-020-3967            5             False    False
# ..           ...          ...               ...      ...
# 995  86-444-4119          996              True     True
# 996  55-326-4821          997             False     True
# 997  03-117-1387          998              True    False
# 998  06-185-9690          999             False    False
# 999  25-976-6934         1000             False     True
#
#      Is the style appealing Source of Product
# 0                      True                TV
# 1                     False             Email
# 2                     False           Website
# 3                      True        Newspapers
# ...

# %% [markdown]
# Transformations in Data 5
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 5
data5_raw_Sales_Of_Fabrics.drop("_id", axis=1, inplace=True)
import seaborn as sns
#displaying heatmap for visualizing null values in rawdataset
sns.heatmap(data5_raw_Sales_Of_Fabrics.isnull(), cmap='viridis')
data5_raw_Sales_Of_Fabrics.isnull().sum()
# Out:
# ID                0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# State             3
# Order Date        0
# Ship Date         0
# Sales             0
# Quantity          0
# Profit            0
# Order Priority    0
# dtype: int64

# %%
data5_raw_Sales_Of_Fabrics['State'].value_counts()
data5_raw_Sales_Of_Fabrics["State"].fillna('Île-de-France', inplace=True)

# %%
data5_raw_Sales_Of_Fabrics.isnull().sum()
# Out:
# ID                0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# State             0
# Order Date        0
# Ship Date         0
# Sales             0
# Quantity          0
# Profit            0
# Order Priority    0
# dtype: int64

# %%
data5_raw_Sales_Of_Fabrics
# Out:
#        ID  Customer ID  Customer Name      Segment        Country  \
# 0       1             1       Barbabra   Consumer         Germany
# 1       2             2           Pate  Corporate          France
# 2       3             3      Aristotle   Consumer          Canada
# 3       4             4         Editha  Corporate          France
# 4       5             5        Hoebart   Consumer   United States
# ..    ...           ...            ...         ...            ...
# 995   996           996        Aeriell   Consumer   United States
# 996   997           997           Andy   Consumer          Canada
# 997   998           998         Bobbie  Corporate          France
# 998   999           999         Benson   Consumer          Canada
# 999  1000          1000          Carla  Corporate          France
#
#                           State  Order Date   Ship Date    Sales  Quantity  \
# 0                 Niedersachsen  18/12/2018  22/02/2018  382.808      6080
# ...

# %% [markdown]
# Transformation in data 6
#
# Checking for missing values  and cleaning the dataset
#
# Performing dimensionality reduction (Removing unwanted columns)

# %%
## Trnsactions for data 5
data6_raw_Transaction_Details.drop("_id", axis=1, inplace=True)
data6_raw_Transaction_Details.drop("Customer ID", axis=1, inplace=True)
data6_raw_Transaction_Details.drop("Date", axis=1, inplace=True)

# %%
data6_raw_Transaction_Details.rename(columns={"ID": "Customer ID"},inplace=True)

# %%
import seaborn as sns
sns.heatmap(data6_raw_Transaction_Details.isnull(), cmap='viridis')
data6_raw_Transaction_Details.isnull().sum()
# Out:
# Customer ID    0
# Transaction    0
# dtype: int64

# %%
data6_raw_Transaction_Details
# Out:
#      Customer ID Transaction
# 0              1      Unpaid
# 1              2      Unpaid
# 2              3      Unpaid
# 3              4      Unpaid
# 4              5        Paid
# ..           ...         ...
# 995          996        Paid
# 996          997      Unpaid
# 997          998      Unpaid
# 998          999        Paid
# 999         1000      Unpaid
#
# [1000 rows x 2 columns]

# %% [markdown]
# Pushing cleaned structured data to SQL server

# %%
# data1_raw_Business_Lead_Table
# data2_raw_Customer_table
# data3_raw_Fabric_Type
# data4_raw_Feedback
# data5_raw_Sales_Of_Fabrics
# data6_raw_Transaction_Details

# %%
# push transformed data 1 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Business_Lead_Table";
try:
    frame= data1_raw_Business_Lead_Table.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Business_Lead_Table has been created successfully.

# %%
# push transformed data 2 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Customer_table";
try:
    frame= data2_raw_Customer_table.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Customer_table has been created successfully.

# %%
# push transformed data 3 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Fabric_Type";
try:
    frame= data3_raw_Fabric_Type.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Fabric_Type has been created successfully.

# %%
# push transformed data 4 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Feedback";
try:
    frame= data4_raw_Feedback.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Feedback has been created successfully.

# %%
# push transformed data 5 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Sales_Of_Fabrics";
try:
    frame= data5_raw_Sales_Of_Fabrics.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Sales_Of_Fabrics has been created successfully.

# %%
# push transformed data 6 to relational database (PostgreSQL)
from sqlalchemy import create_engine
import psycopg2
alchemyEngine           = create_engine('postgresql+psycopg2://postgres:rinubronic@dap-cluster.c2wpf9zggzmf.eu-west-1.rds.amazonaws.com:5432/Leel_Interlinings_SQL_Server', pool_recycle=3600);
postgreSQLConnection    = alchemyEngine.connect();
postgreSQLTable         = "Transaction_Details";
try:
    frame= data6_raw_Transaction_Details.to_sql(postgreSQLTable, postgreSQLConnection, if_exists='replace');

except ValueError as vx:

    print(vx)

except Exception as ex:  

    print(ex)

else:

    print("PostgreSQL Table %s has been created successfully."%postgreSQLTable);

finally:
    postgreSQLConnection.close();
# Out:
# PostgreSQL Table Transaction_Details has been created successfully.

# %%
# data1_raw_Business_Lead_Table
# data2_raw_Customer_table
# data3_raw_Fabric_Type
# data4_raw_Feedback
# data5_raw_Sales_Of_Fabrics
# data6_raw_Transaction_Details
data1_raw_Business_Lead_Table.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Business_Lead_Table.csv', index=False)
data2_raw_Customer_table.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Customer_table.csv', index=False)
data3_raw_Fabric_Type.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Fabric_Type.csv', index=False)
data4_raw_Feedback.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Feedback.csv', index=False)
data5_raw_Sales_Of_Fabrics.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Sales_Of_Fabrics.csv', index=False)
data6_raw_Transaction_Details.to_csv(r'C:\Users\Asus TUF\OneDrive\Desktop\Leel_interlinigs\Transaction_Details.csv', index=False)
